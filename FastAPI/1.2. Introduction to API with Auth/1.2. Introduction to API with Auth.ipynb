# %%
import requests

headers = {
    "Authorization":"Bearer tiE35WlVgEkBj_fHPFsY"
}
response = requests.get("https://the-one-api.dev/v2/movie", headers=headers )
response.status_code
response.json()
# Out:
# {'docs': [{'_id': '5cd95395de30eff6ebccde56',
#    'name': 'The Lord of the Rings Series',
#    'runtimeInMinutes': 558,
#    'budgetInMillions': 281,
#    'boxOfficeRevenueInMillions': 2917,
#    'academyAwardNominations': 30,
#    'academyAwardWins': 17,
#    'rottenTomatoesScore': 94},
#   {'_id': '5cd95395de30eff6ebccde57',
#    'name': 'The Hobbit Series',
#    'runtimeInMinutes': 462,
#    'budgetInMillions': 675,
#    'boxOfficeRevenueInMillions': 2932,
#    'academyAwardNominations': 7,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 66.33333333},
#   {'_id': '5cd95395de30eff6ebccde58',
#    'name': 'The Unexpected Journey',
#    'runtimeInMinutes': 169,
#    'budgetInMillions': 200,
#    'boxOfficeRevenueInMillions': 1021,
#    'academyAwardNominations': 3,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 64},
#   {'_id': '5cd95395de30eff6ebccde59',
#    'name': 'The Desolation of Smaug',
#    'runtimeInMinutes': 161,
#    'budgetInMillions': 217,
# ...

# %%
import requests

url = "https://api.iconfinder.com/v4/icons/search"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 	ZqrJ07rKOiauQSqgSNAI9xXNq4LMNkfubyoIRvfZGA1IokjcB2ga09RZc90LGE5H"
}
payload = {
    "query": "arrow",
    "count": "10"
}

response = requests.get(url, headers=headers, params=payload)
response.status_code
response.json()
# Out:
# {'total_count': 191059,
#  'icons': [{'icon_id': 4470662,
#    'tags': ['app', 'back', 'mobile', 'ui', 'ux', 'web', 'arrow'],
#    'published_at': '2019-04-05T08:53:39.350522',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
# ...

# %%
import requests

url = "https://54285744-illusion-diffusion.gateway.alpha.fal.ai/"

headers = {
    "Authorization": "Key 7ea9f843-bb21-4107-a525-2d0a7876bcce:e79e01d2fcfe0da83a355bb8adda764c",
    "Content-Type": "application/json"
}
payload = {
    "image_url": "https://storage.googleapis.com/falserverless/illusion-examples/pattern.png",
    "prompt": "(masterpiece:1.4), (best quality), (detailed), landscape, Rainy forest of northern Canada",
    "negative_prompt": "(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4, bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t)"
}

response = requests.post(url, headers=headers, json=payload)
response.status_code
response.json()
# Out:
# {'image': {'url': 'https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/github_54285744/2c0412e8e4cb416787b207af93354176_3a987374ed7244a687584af66ebafeb6.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20241029%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241029T052326Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...',
#   'content_type': 'image/png',
#   'file_name': '3a987374ed7244a687584af66ebafeb6.png',
#   'file_size': 2049865,
#   'width': 1024,
#   'height': 1024},
#  'seed': 4373347409612662}

# %%
import requests

url = "https://api.d-id.com/clips"

payload = {
    "presenter_id": "amy-Aq6OmGZnMt",
    "script": {
        "type": "text",
        "subtitles": "false",
        "provider": {
            "type": "microsoft",
            "voice_id": "Sara"
        },
        "input": "Making videos is easy with D-ID",
        "ssml": "false"
    },
    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } }
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik53ek53TmV1R3ptcFZTQjNVZ0J4ZyJ9.....D-EofBqGxUe38_ah4-i11dwMaFy4XnJJHzaXOeQsNrEhi8ZPZKnD5c8ZahBqrTO50x_kJ3S75EbQN31E5IZy6_9mOckgrsjy4xmv0iL36p0c5Br81o--Ole1cr9WRAA0hTc5uisHtOQ0f8wLfT33GV2BPwH_uihByXl_8GrjFFodehpmD_hyuva93LIFseXP4OAbSmeAKXRbvDdIjegc6GmBx6VcRrlVMfKvKpnIk6jaC0WNcSkqQSA9nxMzgdfcg720m08-nqBmrRL7Nq3-fH_uhYKiQ7AJRDPdF8mCCr9sqyha2K_EJarhHERGHyGTwP1upyxEyrkoi977hlgFPA"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"message":"Unauthorized"}

# %%
import requests

url = "https://api.d-id.com/clp_LGdOv2glTmb31KRNnB6nZ"

headers = {
    "accept": "application/json",
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ik53ek53TmV1R3ptcFZTQjNVZ0J4ZyJ9.....D-EofBqGxUe38_ah4-i11dwMaFy4XnJJHzaXOeQsNrEhi8ZPZKnD5c8ZahBqrTO50x_kJ3S75EbQN31E5IZy6_9mOckgrsjy4xmv0iL36p0c5Br81o--Ole1cr9WRAA0hTc5uisHtOQ0f8wLfT33GV2BPwH_uihByXl_8GrjFFodehpmD_hyuva93LIFseXP4OAbSmeAKXRbvDdIjegc6GmBx6VcRrlVMfKvKpnIk6jaC0WNcSkqQSA9nxMzgdfcg720m08-nqBmrRL7Nq3-fH_uhYKiQ7AJRDPdF8mCCr9sqyha2K_EJarhHERGHyGTwP1upyxEyrkoi977hlgFPA"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"Invalid key=value pair (missing equal-sign) in Authorization header (hashed with SHA-256 and encoded with Base64): 'ktZoJaB+sciirsVskk5XFpp/2AYG4/Jw5kZyz3vBjoI='."}

# %%
import requests
import dotenv
import os

url = "https://my-api.plantnet.org/v2/identify/all"
dotenv = dotenv.load_dotenv()
plantnet_API_KEY = os.getenv("plantnet_API_KEY")

headers = {

}
payload = {
    "api-key": plantnet_API_KEY
}
files = {
    "images": open("/content/bequaertii.jpg", "rb")
}

response = requests.post(url, headers=headers, params=payload, files=files)
response.status_code
response.json()
# Out:
# {'query': {'project': 'all',
#   'images': ['5bcafc812c2cad382dbbc1d9c04b864b'],
#   'organs': ['auto'],
#   'includeRelatedImages': False,
#   'noReject': False},
#  'language': 'en',
#  'preferedReferential': 'k-world-flora',
#  'bestMatch': 'Impatiens bequaertii De Wild.',
#  'results': [{'score': 0.75637,
#    'species': {'scientificNameWithoutAuthor': 'Impatiens bequaertii',
#     'scientificNameAuthorship': 'De Wild.',
#     'genus': {'scientificNameWithoutAuthor': 'Impatiens',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Impatiens'},
#     'family': {'scientificNameWithoutAuthor': 'Balsaminaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Balsaminaceae'},
#     'commonNames': [],
#     'scientificName': 'Impatiens bequaertii De Wild.'},
#    'gbif': {'id': '7778796'},
#    'powo': {'id': '103487-1'},
#    'iucn': {'id': '103581580', 'category': 'NT'}},
#   {'score': 0.11274,
# ...
